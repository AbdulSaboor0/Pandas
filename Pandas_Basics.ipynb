# %% [markdown]
# ## **Pandas Basics** 🐼
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Pandas Series**
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
###  Exploring Pandas Series

Data = [3,5,7,9,11]

series = pd.Series(Data)
series
# Out:
# 0     3
# 1     5
# 2     7
# 3     9
# 4    11
# dtype: int64

# %%
df = pd.Series({'A':[1,2,3,4,5], 'B':[2,4,6,8,10]})
df
# Out:
# A     [1, 2, 3, 4, 5]
# B    [2, 4, 6, 8, 10]
# dtype: object

# %%
### Manual Indexing

z = [10,20,30,40, 50]
Index = ['a', 's','d','f','g']

df = pd.Series(z, index = Index)
df
# Out:
# a    10
# s    20
# d    30
# f    40
# g    50
# dtype: int64

# %% [markdown]
# ### **Pandas DataFrame**
#
# ---

# %%
ind = np.arange(1,5)
df = pd.DataFrame(
    { 'Name': ['Naruto','Luffy', 'Gojo','Eren'],
      'City': ['Konoha', 'Japan', 'Shibuya', 'Paradise'],
       'Age': [14, 16, 20, 25 ]
    }
, index = ind)
df
# Out:
#      Name      City  Age
# 1  Naruto    Konoha   14
# 2   Luffy     Japan   16
# 3    Gojo   Shibuya   20
# 4    Eren  Paradise   25

# %%
np.array(df)
# Out:
# array([['Naruto', 'Konoha', 14],
#        ['Luffy', 'Japan', 16],
#        ['Gojo', 'Shibuya', 20],
#        ['Eren', 'Paradise', 25]], dtype=object)

# %% [markdown]
# ### **Reading Data from a file**
#
# ---

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/pokemon_data.csv')

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail(6)
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 794       95     95           6       True
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# ### **Accessing the data from df**
#
# ---

# %%
### Getting the column names/ Headers

df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total'],
#       dtype='object')

# %%
 ###  For Column contents

df[
    ['Name', 'HP']
    ]
# Out:
#                       Name  HP
# 0                Bulbasaur  46
# 1                  Ivysaur  61
# 2                 Venusaur  81
# 3    VenusaurMega Venusaur  81
# 4               Charmander  40
# ..                     ...  ..
# 795                Diancie  51
# 796    DiancieMega Diancie  51
# 797    HoopaHoopa Confined  81
# 798     HoopaHoopa Unbound  81
# 799              Volcanion  81
#
# [800 rows x 2 columns]

# %%
### For Rows (.loc / .iloc)

df.iloc[0][1]
# Out:
# 'Bulbasaur'

# %%
### Accessing a Specific element

df.at[0, 'Type 1']
# Out:
# 'Grass'

# %% [markdown]
# ### **Data Manipulation**
#
# ---

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
### Adding a new column
### ADDING A NEW COLUMN IS A PERMANENT OPERATION SO THE CHANGE WILL OCCOUR TO YOUR DATASET

df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# 1         80       80     60           1      False    405
# 2        100      100     80           1      False    525
# 3        122      120     80           1      False    625
# 4         60       50     65           1      False    309
# ..       ...      ...    ...         ...        ...    ...
# 795      100      150     50           6       True    600
# 796      160      110    110           6       True    700
# 797      150      130     70           6       True    600
# 798      170      130     80           6       True    680
# 799      130       90     70           6       True    600
#
# [800 rows x 13 columns]

# %%
### Removing a column
### REMOVING A NEW COLUMN IS NOT A PERMANENT OPERATION SO THE CHANGE WILL NOT OCCOUR TO YOUR DATASET, INSTEAD MAKE DF2 TO SAVE THE CHANGE OR
### USE THE FOLLOWING CODE df.drop('Column name', axis =1, inplace = True)

df.drop('#', axis =1, inplace= True)
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 0         65     45           1      False    318
# 1         80     60           1      False    405
# 2        100     80           1      False    525
# 3        120     80           1      False    625
# 4         50     65           1      False    309
# ..       ...    ...         ...        ...    ...
# 795      150     50           6       True    600
# 796      110    110           6       True    700
# 797      130     70           6       True    600
# 798      130     80           6       True    680
# 799       90     70           6       True    600
#
# [800 rows x 12 columns]

# %%
### Operations on the columns
df['HP']= df['HP'] +1
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  46      49       49       65
# 1                  Ivysaur    Grass  Poison  61      62       63       80
# 2                 Venusaur    Grass  Poison  81      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  81     100      123      122
# 4               Charmander     Fire     NaN  40      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  51     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  51     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  81     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  81     160       60      170
# 799              Volcanion     Fire   Water  81     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 0         65     45           1      False    318
# 1         80     60           1      False    405
# 2        100     80           1      False    525
# 3        120     80           1      False    625
# 4         50     65           1      False    309
# ..       ...    ...         ...        ...    ...
# 795      150     50           6       True    600
# 796      110    110           6       True    700
# 797      130     70           6       True    600
# 798      130     80           6       True    680
# 799       90     70           6       True    600
#
# [800 rows x 12 columns]

# %%
### Removing a Row from the Data

df.drop([0])
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1                  Ivysaur    Grass  Poison  61      62       63       80
# 2                 Venusaur    Grass  Poison  81      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  81     100      123      122
# 4               Charmander     Fire     NaN  40      52       43       60
# 5               Charmeleon     Fire     NaN  59      64       58       80
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  51     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  51     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  81     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  81     160       60      170
# 799              Volcanion     Fire   Water  81     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 1         80     60           1      False    405
# 2        100     80           1      False    525
# 3        120     80           1      False    625
# 4         50     65           1      False    309
# 5         65     80           1      False    405
# ..       ...    ...         ...        ...    ...
# 795      150     50           6       True    600
# 796      110    110           6       True    700
# 797      130     70           6       True    600
# 798      130     80           6       True    680
# 799       90     70           6       True    600
#
# [799 rows x 12 columns]

# %% [markdown]
# ### **Statistical Analysis**
#
# ---

# %%
df.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    70.258750   79.001250   73.842500   72.820000   71.902500   68.277500
# std     25.534669   32.457366   31.183501   32.722294   27.828916   29.060474
# min      2.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     51.000000   55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     66.000000   75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     81.000000  100.000000   90.000000   95.000000   90.000000   90.000000
# max    256.000000  190.000000  230.000000  194.000000  230.000000  180.000000
#
#        Generation      Total
# count   800.00000  800.00000
# mean      3.32375  435.10250
# std       1.66129  119.96304
# min       1.00000  180.00000
# 25%       2.00000  330.00000
# 50%       3.00000  450.00000
# 75%       5.00000  515.00000
# max       6.00000  780.00000
